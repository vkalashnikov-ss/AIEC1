# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[2], line 8
#       4 model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
#       5
#       6 llm = ChatFireworks(model=model_endpoint)
#       7
# ----> 8 response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
#       9 print(response.content)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_fireworks/chat_models.py:840, in ChatFireworks._generate(self, messages, stop, run_manager, stream, **kwargs)
#     834 message_dicts, params = self._create_message_dicts(messages, stop)
#     835 params = {
#     836     **params,
#     837     **({"stream": stream} if stream is not None else {}),
#     838     **kwargs,
#     839 }
# --> 840 response = _completion_with_retry(
#     841     self, run_manager=run_manager, messages=message_dicts, **params
#     842 )
#     843 return self._create_chat_result(response)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_fireworks/chat_models.py:497, in _completion_with_retry(llm, run_manager, **kwargs)
#     494         return _prepend_chunk(first, iterator)
#     495     return result
# --> 497 return _call()
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File ~/.local/share/uv/python/cpython-3.13.2-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.13.2-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_fireworks/chat_models.py:481, in _completion_with_retry.<locals>._call()
#     479     result = llm.client.create(**kwargs)
#     480 except httpx.HTTPStatusError as e:
# --> 481     _promote_http_status_error(e)
#     482 if kwargs.get("stream"):
#     483     # The streaming generator is lazy — advance once so the HTTP
#     484     # connection and any transport error happen inside the retry
#     485     # boundary. `_prepend_chunk` then re-yields the consumed chunk
#     486     # ahead of the rest so callers still see every event.
#     487     try:
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_fireworks/chat_models.py:436, in _promote_http_status_error(exc)
#     434     msg = f"Retryable {exc.response.status_code} from Fireworks: {exc}"
#     435     raise _RetryableHTTPStatusError(msg) from exc
# --> 436 raise exc
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_fireworks/chat_models.py:479, in _completion_with_retry.<locals>._call()
#     476 @retry_decorator
#     477 def _call() -> Any:
#     478     try:
# --> 479         result = llm.client.create(**kwargs)
#     480     except httpx.HTTPStatusError as e:
#     481         _promote_http_status_error(e)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/chat_completion.py:41, in ChatCompletionV2.create(self, model, prompt_or_messages, request_timeout, stream, extra_headers, **kwargs)
#      32 def create(
#      33     self,
#      34     model,
#    (...)     39     **kwargs,
#      40 ):
# ---> 41     return super().create(
#      42         model,
#      43         prompt_or_messages,
#      44         request_timeout,
#      45         stream=stream,
#      46         client=self._client,
#      47         extra_headers=extra_headers,
#      48         **self._validate_kwargs(kwargs),
#      49     )
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/base_completion.py:81, in BaseCompletion.create(cls, model, prompt_or_messages, request_timeout, stream, client, extra_headers, **kwargs)
#      73     return cls._create_streaming(
#      74         model,
#      75         request_timeout,
#    (...)     78         **kwargs,
#      79     )
#      80 else:
# ---> 81     return cls._create_non_streaming(
#      82         model,
#      83         request_timeout,
#      84         client=client,
#      85         extra_headers=extra_headers,
#      86         **kwargs,
#      87     )
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/base_completion.py:180, in BaseCompletion._create_non_streaming(cls, model, request_timeout, client, extra_headers, **kwargs)
#     178 client = client or FireworksClient(request_timeout=request_timeout)
#     179 data = {"model": model, "stream": False, **kwargs}
# --> 180 response = client.post_request_non_streaming(
#     181     f"{client.base_url}/{cls.endpoint}",
#     182     data=data,
#     183     extra_headers=extra_headers,
#     184 )
#     185 return cls.response_class(**response)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/api_client.py:160, in FireworksClient.post_request_non_streaming(self, url, data, extra_headers)
#     153 def post_request_non_streaming(
#     154     self,
#     155     url: str,
#     156     data: Optional[Dict[str, Any]] = None,
#     157     extra_headers: Optional[Dict[str, str]] = None,
#     158 ) -> Dict[str, Any]:
#     159     response = self._client.post(url, json=data, headers=self._get_headers(extra_headers))
# --> 160     self._error_handling(response)
#     161     return response.json()
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/api_client.py:124, in FireworksClient._error_handling(self, resp)
#     122 if resp.is_error:
#     123     resp.read()
# --> 124 self._raise_for_status(resp)
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/api_client.py:114, in FireworksClient._raise_for_status(self, response)
#     103         return json.dumps(
#     104             {
#     105                 "error": {
#    (...)    110             }
#     111         )
#     113 self._raise_for(response.status_code, get_error_message)
# --> 114 response.raise_for_status()
#
# File ~/Documents/repos/ai-maker-space/AIEC1/10_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Redirect response '302 Found' for url 'https://api.fireworks.ai/inference/v1/chat/completions'
# Redirect location: 'https://blocked.teams.cloudflare.com/?timestamp=1783036142&background_color=%23072338&device_id=7cd9822b-05b9-11f0-8977-3239d4eb835e&url=https%3A%2F%2Fapi.fireworks.ai%2Finference%2Fv1%2Fchat%2Fcompletions&logo_path=http%3A%2F%2Fsixthstreet.com%2Fwp-content%2Fuploads%2F2020%2F06%2FSixth-Street_PRINT-1.svg&mailto_address=Tech-Support%40sixthstreet.com&suppress_footer=false&account_id=714733433f94278ecbde8226dca9d8ec&mailto_subject=Blocked+url&params_sign=W%2BUtWRIXQkFt%2FQ8E42gKSKQczy3PSYrtm9YjJV%2FV70E%3D&header_text=Page+Blocked&footer_text=Access+to+this+page+is+blocked+for+security+or+compliance+reasons.+To+unblock+it%2C+please+click+%22Contact+Your+Administrator%2C%22+provide+a+business+justification%2C+and+click+%22Send%22+to+create+a+ticket+for+Tech+Support+to+review+your+request.&source_ip=32.221.166.117%3A65114&user_id=a1372513-27b8-5638-a4a6-12163f53521a&name=Sixth+Street+Partners&rule_id=a6420d6e-e1fe-4e10-a5e2-763c61a16d6e'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/302

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 20: If a wood‑chuck could chuck wood at all, folklore says—“as m...
# Response 24: A woodchuck would chuck about as much wood as could fit in i...
# Response 16: If a woodchuck could actually chuck wood, the folklore (and ...
# Response 3: A humorously accepted answer is that a woodchuck could chuck...
# Response 23: The classic answer to this tongue‑twister is, “**About 700 p...
# Response 5: The classic tongue‑twister leaves a lot to the imagination, ...
# Response 1: The classic answer to the tongue‑twister is that a woodchuck...
# Response 14: The classic answer is that a wood‑chuck wouldn’t actually ge...
# Response 6: The classic tongue‑twister never requires a precise science‑...
# Response 4: In the classic tongue‑twister, the folk answer is that a woo...
# Response 22: It’s a tongue‑twister, not a math problem, so the “answer” i...
# Response 8: The classic answer to the tongue‑twister is: **“A woodchuck ...
# Response 21: If a wood chuck could chuck wood, the old tongue‑twister doe...
# Response 11: The tongue‑twisters around the world never quite tell us the...
# Response 15: **Answer:**
#
# According to a 1988 study by wildlife biologist...
# Response 19: A woodchuck (aka a groundhog) would chuck roughly **700 poun...
# Response 9: 🎶 **“How Much Wood?” – The Legendary Woodchuck Riddle**
#
# > “...
# Response 2: It’s a classic tongue‑twister rather than a hard science que...
# Response 7: They never really did—it's a tongue‑twister, not a real phys...
# Response 17: It’s a classic tongue‑twister, not a literal fact, but the m...
# Response 12: Ah, the great mill‑ennial rhyme that never quite stopped the...
# Response 13: **Short answer:**
# > “A wood‑chuck would chuck… **about 700...
# Response 18: The classic tongue‑twister doesn’t really have a mathematica...
# Response 10: **The classic answer**
# > *“He would chuck as much wood as ...
